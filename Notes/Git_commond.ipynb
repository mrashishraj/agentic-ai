# %% [markdown]
# #### For the daily push Use below Commond

# %%
git add .
git commit m "your message"
git push

# %% [markdown]
# #### To start any new repo push, First install the git in the folder

# %%
git init
git add .
git commit m "add commit"
git remote add origin https://github.com/{yourusername}/{yourreponame}
git push u origin main

# %% [markdown]
# #### To check all git folder

# %%
find . name ".git" type d

# %% [markdown]
# #### To find all file by it it's size in git commit

# %%
find . size +5M not path "./.git/*"

# %% [markdown]
# #### Venv को tracking से हटाओ

# %%
git rm r cached Python/UVVenv/

# %% [markdown]
#
#
#
#  git add .
#  git commit m "remove venv, add gitignore"
#
# # 3. फिर push करो
#  git push u origin main
