# %% [markdown]
# ## Conda virtual environment and activate this

# %%
conda create -p venv python==3.12
conda activate venv/

# %% [markdown]
# ## Create python virtual environment

# %% [markdown]
# python -m venv myvenv
# source venv/bin/activate

# %% [markdown]
# ## Remove the existing env

# %% [markdown]
# conda deactivate
# conda env remove -p "/Users/ashishraj/Documents/My-Docs/Agentic AI/Langchain/venv"
