# %% [markdown]
# ### To install library from requirement.txt

# %%
pip install -r requirement.txt

# %% [markdown]
# ## Force reinstall any specific version

# %%
pip install arxiv==2.1.3 --force-reinstall
