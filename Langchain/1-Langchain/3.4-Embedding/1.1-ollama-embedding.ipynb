# %% [markdown]
# # Ollama

# %% [markdown]
# #### Ollama supports embadding models, making it possible to build retrieval augmented generation (RAG) applications that combine text prompt with existing documents or other data.

# %%
from langchain_community.embeddings import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="nomic-embed-text"
)

result = embeddings.embed_documents([
    "What is the second letter of greek alphabet "
])



print(result)
print(len(result[0]))  # Embedding dimension
# Out:
# [[0.24468274414539337, 0.5112143158912659, -3.145217180252075, -1.7822774648666382, 1.4698528051376343, -0.7145925164222717, -0.3933992385864258, -0.26803261041641235, -0.3452815115451813, -0.347171813249588, -1.1625287532806396, 2.470003128051758, 1.5143617391586304, 0.5319837331771851, 0.9703407883644104, -0.8916685581207275, 1.2502117156982422, -0.5960044860839844, -0.19981691241264343, 0.24826201796531677, -1.008255958557129, 0.17133024334907532, -0.829816460609436, -0.27801474928855896, 2.5104472637176514, 1.5480948686599731, 1.1605734825134277, 0.6016876697540283, -1.2314624786376953, -1.3341093063354492, 0.010978369042277336, -0.39680665731430054, 0.6700950264930725, -0.6888934373855591, -0.9481549263000488, -0.07369537651538849, 0.5036200881004333, 1.0598188638687134, -0.4507821202278137, 0.004528417252004147, 0.9182685613632202, -0.8866855502128601, -0.1305084377527237, -0.5678459405899048, 0.9849374890327454, -1.1196781396865845, -0.6853210926055908, 0.29280003905296326, 0.
# ...

# %%
## other embeding model
## https://ollama.com/library/mxbai-embed-large

embeddings = OllamaEmbeddings(
    model="mxbai-embed-large"
)
text = "this is just a test"
result = embeddings.embed_documents([text])
print(result)
len(result[0])  # Embedding dimension
# Out:
# [[0.03554331138730049, -0.0023959411773830652, 0.02207484096288681, 0.028387943282723427, -0.04803355783224106, -0.03983569145202637, 0.005273040849715471, -0.02539428137242794, 0.01735125295817852, 0.05753849819302559, 0.01977606490254402, 0.02197917364537716, 0.007186316419392824, -0.02689199522137642, -0.028700318187475204, -0.042821697890758514, -0.037115901708602905, 0.03196621313691139, -0.0043770931661129, -0.0022449640091508627, -0.029384039342403412, 0.009794212877750397, -0.0205211341381073, -0.003878107527270913, -0.02997661381959915, 0.020363278687000275, -0.010767752304673195, 0.006501524243503809, 0.030252663418650627, 0.034083303064107895, -0.009991820901632309, 0.018023405224084854, -0.002707279985770583, -0.02642158605158329, 0.014272204600274563, -0.025565581396222115, 0.06838376075029373, -0.04102961719036102, -0.027594590559601784, -0.01762089505791664, -0.01714370958507061, 0.00934595800936222, 0.04485128074884415, -0.0010831098770722747, -0.0566897876560688, -0.
# ...
